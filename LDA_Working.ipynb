# %%
from __future__ import print_function

# %%
import pyLDAvis
import pyLDAvis.sklearn
pyLDAvis.enable_notebook()
from sklearn.datasets import fetch_20newsgroups
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.decomposition import LatentDirichletAllocation

import Configuration 
import Utils
# Out:
# D:\Tema NTNU\Code\Final_App_Thesis_2017\Final_App_Thesis_2017\Configuration.py:28: DeprecationWarning: invalid escape sequence \T
#   "Nulled_Test":["Nulled\Thesis_Test_Data_1M.txt"]
# c:\users\isuf\appdata\local\programs\python\python36\lib\site-packages\gensim\utils.py:855: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")
# c:\users\isuf\appdata\local\programs\python\python36\lib\site-packages\scipy\sparse\sparsetools.py:20: DeprecationWarning: `scipy.sparse.sparsetools` is deprecated!
# scipy.sparse.sparsetools is a private module for scipy.sparse, and should not be used.
#   _deprecated()
# c:\users\isuf\appdata\local\programs\python\python36\lib\site-packages\nltk\decorators.py:59: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() or inspect.getfullargspec()
#   regargs, varargs, varkwargs, defaults = inspect.getargspec(func)
# ...

# %%
params = Configuration.Parameters()
file_locations=params.file_locations
param = params.param
# Out:
# c:\users\isuf\appdata\local\programs\python\python36\lib\json\encoder.py:199: DeprecationWarning: Interpreting naive datetime as local 2017-05-05 20:10:18.433406. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)

# %%
data_folder=[params.baseline_locations["Binary_All"][0]]
docs, vocab = Utils.load(data_folder,clean_string=True,remove_stop_words=False,split_for_cv=True)
max_l= Utils.get_dataset_details(docs,vocab)
labels = [sent["y"] for sent in docs]
data = [ sent["text"] for sent in docs]
# Out:
# Number of empty sentences : 0
# data loaded!
#          number of documents: 15996
#          vocab size: 154191
#          max document length: 250
#          avg document length: 52.4164166042
#          min document length: 1
#          max char length: 6752
#          avg char length: 330.024193548
#          min char length: 1

# %%
tf_vectorizer = CountVectorizer(max_df=0.5, min_df=1,lowercase = True,
                                    stop_words='english')
dtm_tfidf = tf_vectorizer.fit_transform(data)

lda_tfidf = LatentDirichletAllocation(n_topics=20, random_state=0,learning_method='online')
lda_tfidf.fit(dtm_tfidf)
# Out:
# LatentDirichletAllocation(batch_size=128, doc_topic_prior=None,
#              evaluate_every=-1, learning_decay=0.7,
#              learning_method='online', learning_offset=10.0,
#              max_doc_update_iter=100, max_iter=10, mean_change_tol=0.001,
#              n_jobs=1, n_topics=20, perp_tol=0.1, random_state=0,
#              topic_word_prior=None, total_samples=1000000.0, verbose=0)

# %%
pyLDAvis.sklearn.prepare(lda_tfidf, dtm_tfidf, tf_vectorizer)
# Out:
# PreparedData(topic_coordinates=            Freq  cluster  topics         x         y
# topic
# 3      28.472825        1       1 -0.347727 -0.317770
# 1      19.279241        1       2 -0.327001  0.263090
# 7       5.647421        1       3 -0.168879  0.121718
# 8       4.771570        1       4 -0.043711  0.088089
# 10      4.635374        1       5 -0.038458 -0.071664
# 2       3.848098        1       6  0.030576  0.007128
# 9       2.582588        1       7  0.031819 -0.052747
# 18      2.574942        1       8  0.037238 -0.037264
# 12      2.516792        1       9  0.066205  0.004067
# 19      2.499981        1      10  0.057185 -0.008612
# 13      2.489303        1      11  0.069473  0.005720
# 5       2.434440        1      12  0.072618 -0.000084
# 11      2.403073        1      13  0.057522  0.005279
# 17      2.381302        1      14  0.072654 -0.002336
# 0       2.271044        1      15  0.075348  0.000818
# 4       2.269123        1      16  0.074933  0.002107
# ...
